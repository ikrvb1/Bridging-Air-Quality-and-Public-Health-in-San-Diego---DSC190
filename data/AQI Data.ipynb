# %%
import pandas as pd

aqi_2021 = pd.read_csv('ad_viz_plotval_data.csv')
aqi_2022 = pd.read_csv('ad_viz_plotval_data (1).csv')
aqi_2023 = pd.read_csv('ad_viz_plotval_data (2).csv')
aqi_2024 = pd.read_csv('ad_viz_plotval_data (3).csv')
aqi_2025 = pd.read_csv('ad_viz_plotval_data (4).csv')

# %%
aqi_2021.shape[0] + aqi_2022.shape[0] + aqi_2023.shape[0] + aqi_2024.shape[0] + aqi_2025.shape[0]
# Out:
# 14489

# %%
aqi_all = pd.concat(
    [aqi_2021, aqi_2022, aqi_2023, aqi_2024, aqi_2025],
    axis=0,
    ignore_index=True
)

aqi_all.shape
# Out:
# (14489, 21)

# %%
aqi_all['Local Site Name'].unique()
# Out:
# array(['Chula Vista', 'Alpine', 'Camp Pendleton', 'Donovan',
#        'San Diego - Kearny Villa Rd.',
#        'El Cajon - Lexington Elementary School',
#        'San Diego - Sherman Elementary School', 'Pala Airpad',
#        'La Posta Band of Indians'], dtype=object)

# %%
df.to_csv("my_data.csv", index=False)
# Out:
# ',Date,Source,Site ID,POC,Daily Max 8-hour Ozone Concentration,Units,Daily AQI Value,Local Site Name,Daily Obs Count,Percent Complete,AQS Parameter Code,AQS Parameter Description,Method Code,CBSA Code,CBSA Name,State FIPS Code,State,County FIPS Code,County,Site Latitude,Site Longitude\r\n0,01/01/2021,AQS,60730001,1,0.04,ppm,37,Chula Vista,17,100.0,44201,Ozone,47.0,41740,"San Diego-Carlsbad, CA",6,California,73,San Diego,32.6312420008573,-117.059088\r\n1,01/02/2021,AQS,60730001,1,0.038,ppm,35,Chula Vista,17,100.0,44201,Ozone,47.0,41740,"San Diego-Carlsbad, CA",6,California,73,San Diego,32.6312420008573,-117.059088\r\n2,01/03/2021,AQS,60730001,1,0.041,ppm,38,Chula Vista,17,100.0,44201,Ozone,47.0,41740,"San Diego-Carlsbad, CA",6,California,73,San Diego,32.6312420008573,-117.059088\r\n3,01/04/2021,AQS,60730001,1,0.039,ppm,36,Chula Vista,17,100.0,44201,Ozone,47.0,41740,"San Diego-Carlsbad, CA",6,California,73,San Diego,32.6312420008573,-117.059088\r\n4,01/05/2021,AQS,60730001,1,0.034,ppm,
# ...

# %%
import folium

sites = aqi_all[["Local Site Name", "Site Latitude", "Site Longitude"]].dropna().drop_duplicates()

m = folium.Map(
    location=[sites["Site Latitude"].mean(), sites["Site Longitude"].mean()],
    zoom_start=9,
    tiles="CartoDB positron"
)

for _, row in sites.iterrows():
    folium.Marker(
        location=[row["Site Latitude"], row["Site Longitude"]],
        popup=row["Local Site Name"],
    ).add_to(m)

m  # displays in Jupyter
# Optional: save to share
# m.save("aqi_sites_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# !pip install folium
# Out:
# ...
#    ---------------------------------------- 0.0/113.4 kB ? eta -:--:--
#    ---------------------------------------  112.6/113.4 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 113.4/113.4 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/93.9 kB ? eta -:--:--
#    ---------------------------------------- 93.9/93.9 kB 2.7 MB/s eta 0:00:00
# ...
